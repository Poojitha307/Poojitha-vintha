# %%
from transformers import pipeline

# %%
image_captioner = pipeline("image-to-text", model='Salesforce/blip-image-captioning-large',device=0)
# Out:
# config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
image = r'/content/panda 10.jpg'
caption = image_captioner(image)
caption[0].get('generated_text')
# Out:
# 'panda bear eating bamboo in zoo exhibit with green leaves in mouth'

# %%
vqa = pipeline('visual-question-answering')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision d0a1f6a (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/470M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
q = input('Ask a question about the image:')
result = vqa(image,q)
result
# Out:
# Ask a question about the image:what is the animal
# [{'score': 0.9949880838394165, 'answer': 'panda'},
#  {'score': 0.061991263180971146, 'answer': 'bear'},
#  {'score': 0.011425714939832687, 'answer': 'polar bear'},
#  {'score': 0.010207271203398705, 'answer': 'zebra'},
#  {'score': 0.007477041333913803, 'answer': 'black and white'}]

# %%
# !pip install diffusers
import torch
from diffusers import DiffusionPipeline
generator = DiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
generator.to("cuda")
# Out:
# ...
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# ...

# %%
prompt = input("Enter the prompt:")
image = generator(prompt).images[0]
image
# Out:
# Enter the prompt:MOUNTAINS
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from transformers import pipeline
img_cls = pipeline('image-classification')
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326 (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Device set to use cuda:0

# %%
img = "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQ_9ua4ubaHPYlz5lGZDbnbaXVoYyWGqMZS6o24_VB4-VEngCejd8-z6hcTUNz3Op7i0gyc291_K7gfenudoW_qKQ"

# %%
r = img_cls(img)
r
# Out:
# [{'label': 'chow, chow chow', 'score': 0.9942739605903625},
#  {'label': 'Tibetan mastiff', 'score': 0.0027980452869087458},
#  {'label': 'Tibetan terrier, chrysanthemum dog',
#   'score': 0.0005662654875777662},
#  {'label': 'Newfoundland, Newfoundland dog', 'score': 0.0002478877722751349},
#  {'label': 'Pomeranian', 'score': 0.00017705080972518772}]

# %%
det = pipeline("object-detection")
# Out:
# No model was supplied, defaulted to facebook/detr-resnet-50 and revision 1d5f47b (https://huggingface.co/facebook/detr-resnet-50).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/4.59k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# ...

# %%
r = det("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgW87SBZM1tD056unNTL9wu1mBZyC9V16hlw&s")

# %%
r
# Out:
# [{'score': 0.5271490216255188,
#   'label': 'clock',
#   'box': {'xmin': 85, 'ymin': 21, 'xmax': 191, 'ymax': 159}},
#  {'score': 0.965386152267456,
#   'label': 'clock',
#   'box': {'xmin': 85, 'ymin': 39, 'xmax': 189, 'ymax': 158}},
#  {'score': 0.7123039960861206,
#   'label': 'clock',
#   'box': {'xmin': 91, 'ymin': 59, 'xmax': 187, 'ymax': 155}}]

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.8 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=2de5958621ea27a81b9649e16ce0403ee0f1a57020069c2e67fd15dfcdfa4818
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
# !pip install deepface librosa SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 66.1 MB/s eta 0:00:00
# ...

# %%
from deepface import DeepFace
import librosa
import speech_recognition as sr
import numpy as np
# Out:
# 25-05-22 08:59:20 - Directory /root/.deepface has been created
# 25-05-22 08:59:20 - Directory /root/.deepface/weights has been created

# %%
emotions = ['happy','sad','neutral','angry','fear','surprise']

# %%
r = DeepFace.analyze(img_path='/content/lollol.jpg', actions=['emotion'])
r[0]
# Out:
# 25-05-22 09:17:44 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 114MB/s]
# {'emotion': {'angry': np.float32(1.03450475e-07),
#   'disgust': np.float32(3.8151814e-14),
#   'fear': np.float32(1.958871e-06),
#   'happy': np.float32(99.97974),
#   'sad': np.float32(0.0003242075),
#   'surprise': np.float32(0.00044398682),
#   'neutral': np.float32(0.01950293)},
#  'dominant_emotion': 'happy',
#  'region': {'x': 32,
#   'y': 19,
#   'w': 74,
#   'h': 74,
#   'left_eye': None,
#   'right_eye': None},
#  'face_confidence': np.float64(0.93)}

# %%
# !pip install transformers torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...
